# %% [markdown]
# # Data Loaders

# %% [markdown]
# **Warning**
# Running the cell below will download all of the datasets given above and store it for our train test split. Make sure that you have 20gb of data left in your storage.
#
# **Arguments**
# > !python [`<file_name>`].py [`--download/-D`]  [`--save/-S`]
#
# * `filename` - Name of python file
# * `--download/-D` - Downloads the file. If zipped. It will automatically unzipped . Path directory will be sett on dataset
# * `--save/-S` - saving the dataset that has been extracted and converted to `X_train`, `X_test`, `y_train`, `y_test`

# %%
# !python load-datasets/asoul-image-load.py  -D -S
# Out:
# ==============================================================
# 	 Asoul Image Dataset
# ==============================================================
# ==============================================================
# 	 downloading...
# ==============================================================
# ==============================================================
# 	 Done downloading
# ==============================================================
# ==============================================================
# 	 unzipping files...
# ==============================================================
# ==============================================================
# 	 Done unzipping
# ==============================================================

# %%
# !python load-datasets/cellular-image.py --download --save
# Out:
# ==============================================================
# 	 Cellular Image Dataset
# ==============================================================
# ==============================================================
# 	 downloading...
# ==============================================================
# ==============================================================
# 	 Done downloading
# ==============================================================
# ==============================================================
# 	 unzipping files...
# ==============================================================
# ==============================================================
# 	 Done unzipping
# ==============================================================

# %%
# !python load-datasets/food-11.py -D -S
# Out:
# ==============================================================
# 	 Food 11 Dataset
# ==============================================================
# ==============================================================
# 	 downloading...
# ==============================================================
# ==============================================================
# 	 Done downloading
# ==============================================================
# ==============================================================
# 	 unzipping files...
# ==============================================================
# ==============================================================
# 	 Done unzipping
# ==============================================================

# %%
# !python load-datasets/indoor-scenes.py --download --save
# Out:
# ==============================================================
# 	 Indoor Scenes dataset
# ==============================================================
# ==============================================================
# 	 downloading...
# ==============================================================
# ==============================================================
# 	 Done downloading
# ==============================================================
# ==============================================================
# 	 unzipping files...
# ==============================================================
# ==============================================================
# 	 Done unzipping
# ==============================================================

# %%
# !python load-datasets/intel-image.py --download --save
# Out:
# ==============================================================
# 	 Intel image dataset
# ==============================================================
# ==============================================================
# 	 downloading...
# ==============================================================
# ==============================================================
# 	 Done downloading
# ==============================================================
# ==============================================================
# 	 unzipping files...
# ==============================================================
# ==============================================================
# 	 Done unzipping
# ==============================================================

# %%
# !python load-datasets/medical-image.py --download --save
# Out:
# ==============================================================
# 	 Medical Image dataset
# ==============================================================
# ==============================================================
# 	 downloading...
# ==============================================================
# ==============================================================
# 	 Done downloading
# ==============================================================
# ==============================================================
# 	 unzipping files...
# ==============================================================
# ==============================================================
# 	 Done unzipping
# ==============================================================

# %%
# !python load-datasets/sum397.py --download --save
# Out:
# ==============================================================
# 	 Sum 397 dataset
# ==============================================================
# ==============================================================
# 	 downloading...
# ==============================================================
# ==============================================================
# 	 Done downloading
# ==============================================================
# ==============================================================
# 	 unzipping files...
# ==============================================================
# ==============================================================
# 	 Done unzipping
# ==============================================================
